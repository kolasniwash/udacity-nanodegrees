# %% [markdown]
# # Detecting Payment Card Fraud
#
# In this section, we'll look at a credit card fraud detection dataset, and build a binary classification model that can identify transactions as either fraudulent or valid, based on provided, *historical* data. In a [2016 study](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), it was estimated that credit card fraud was responsible for over 20 billion dollars in loss, worldwide. Accurately detecting cases of fraud is an ongoing area of research.
#
# <img src=notebook_ims/fraud_detection.png width=50% />
#
# ### Labeled Data
#
# The payment fraud data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data). This has features and labels for thousands of credit card transactions, each of which is labeled as fraudulent or valid. In this notebook, we'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.
#
# ### Binary Classification
#
# Since we have true labels to aim for, we'll take a **supervised learning** approach and train a binary classifier to sort data into one of our two transaction classes: fraudulent or valid.  We'll train a model on training data and see how well it generalizes on some test data.
#
# The notebook will be broken down into a few steps:
# * Loading and exploring the data
# * Splitting the data into train/test sets
# * Defining and training a LinearLearner, binary classifier
# * Making improvements on the model
# * Evaluating and comparing model test performance
#
# ### Making Improvements
#
# A lot of this notebook will focus on making improvements, as discussed in [this SageMaker blog post](https://aws.amazon.com/blogs/machine-learning/train-faster-more-flexible-models-with-amazon-sagemaker-linear-learner/). Specifically, we'll address techniques for:
#
# 1. **Tuning a model's hyperparameters** and aiming for a specific metric, such as high recall or precision.
# 2. **Managing class imbalance**, which is when we have many more training examples in one class than another (in this case, many more valid transactions than fraudulent).
#
# ---

# %% [markdown]
# First, import the usual resources.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 

import boto3
import sagemaker
from sagemaker import get_execution_role

# %matplotlib inline

# %% [markdown]
# I'm storing my **SageMaker variables** in the next cell:
# * sagemaker_session: The SageMaker session we'll use for training models.
# * bucket: The name of the default S3 bucket that we'll use for data storage.
# * role: The IAM role that defines our data and model permissions.

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Loading and Exploring the Data
#
# Next, I am loading the data and unzipping the data in the file `creditcardfraud.zip`. This directory will hold one csv file of all the transaction data, `creditcard.csv`.
#
# As in previous notebooks, it's important to look at the distribution of data since this will inform how we develop a fraud detection model. We'll want to know: How many data points we have to work with, the number and type of features, and finally, the distribution of data over the classes (valid or fraudulent).

# %%
# only have to run once
# !wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# !unzip creditcardfraud
# Out:
# --2019-12-18 17:35:59--  https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.143.158
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.143.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  12.9MB/s    in 6.2s
#
# 2019-12-18 17:36:05 (10.7 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]
#
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### EXERCISE: Calculate the percentage of fraudulent data
#
# Take a look at the distribution of this transaction data over the classes, valid and fraudulent.
#
# Complete the function `fraudulent_percentage`, below. Count up the number of data points in each class and calculate the *percentage* of the data points that are fraudulent.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    
    # your code here
    fraud_cases = transaction_df['Class'].sum()
    
    return fraud_cases / transaction_df.shape[0]

# %% [markdown]
# Test out your code by calling your function and printing the result.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', fraud_percentage)
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.001727485630620034
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# ### EXERCISE: Split into train/test datasets
#
# In this example, we'll want to evaluate the performance of a fraud classifier; training it on some training data and testing it on *test data* that it did not see during the training process. So, we'll need to split the data into separate training and test sets.
#
# Complete the `train_test_split` function, below. This function should:
# * Shuffle the transaction data, randomly
# * Split it into two sets according to the parameter `train_frac`
# * Get train/test features and labels
# * Return the tuples: (train_features, train_labels), (test_features, test_labels)

# %%
np.random.randint(0, len(transaction_df), len(transaction_df))
# Out:
# array([   925, 151635,  24695, ..., 248297,  13684, 201056])

# %%
# split into train/test
def train_test_split(transaction_df, train_frac= 0.7, seed=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: Two tuples (in order): (train_features, train_labels), (test_features, test_labels)
       '''
    #set a random index
    np.random.seed(seed)
    shuffle_idx = np.random.randint(0, len(transaction_df), len(transaction_df))
    transaction_df = transaction_df.iloc[shuffle_idx, :]
    
    #alternative solution
#     df_matrix = transaction_df.as_matrix()
#     np.random.shuffle(df_matrix)
    
    #index of train/test split
    train_frac_idx = int(transaction_df.shape[0] * train_frac)
    
    #set the labels and features arrays
    labels = transaction_df['Class'].values
    features = transaction_df.drop('Class', axis=1).values
    
    # shuffle and split the data
    train_features = features[:train_frac_idx,:]
    train_labels = labels[:train_frac_idx]
    test_features = features[train_frac_idx:,:]
    test_labels = labels[train_frac_idx:]
    
    return (train_features, train_labels), (test_features, test_labels)

# %% [markdown]
# ### Test Cell
#
# In the cells below, I'm creating the train/test data and checking to see that result makes sense. The tests below test that the above function splits the data into the expected number of points and that the labels are indeed, class labels (0, 1).

# %%
# get train/test data
(train_features, train_labels), (test_features, test_labels) = train_test_split(transaction_df, train_frac=0.7)

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features[0])
print('Label: ', train_labels[0])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199364
# Test data pts:  85443
#
# First item:
#  [ 7.85760000e+04 -7.07635006e-01  4.93302266e-01  2.64808871e+00
#   1.06480660e+00 -6.80271312e-01  1.18383798e+00  1.69412558e-01
#   7.45529637e-02  1.24798788e+00 -3.67903568e-01 -1.12257999e+00
#   8.28645996e-01  3.26756295e-01 -1.53244237e+00 -1.67725518e+00
#  -1.13063924e+00  4.91311772e-01 -8.47915343e-01  7.84634550e-02
#  -1.43785784e-01 -1.02349568e-01  3.23974972e-01 -1.72600781e-01
#   1.26965193e-01 -1.99840340e-03 -3.98741314e-01 -3.85588609e-01
#  -2.05588932e-01  5.78000000e+01]
# Label:  0
#
# Tests passed!

# %% [markdown]
# ---
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# In this notebook, you'll define and train the SageMaker, built-in algorithm, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# A LinearLearner has two main applications:
# 1. For regression tasks in which a linear line is fit to some data points, and you want to produce a predicted output value given some data point (example: predicting house prices given square area).
# 2. For binary classification, in which a line is separating two classes of data and effectively outputs labels; either 1 for data that falls above the line or 0 for points that fall on or below the line.
#
# <img src='notebook_ims/linear_separator.png' width=50% />
#
# In this case, we'll be using it for case 2, and we'll train it to separate data into our two classes: valid or fraudulent.

# %% [markdown]
# ### EXERCISE: Create a LinearLearner Estimator
#
# You've had some practice instantiating built-in models in SageMaker. All estimators require some constructor arguments to be passed in. See if you can complete this task, instantiating a LinearLearner estimator, using only the [LinearLearner documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) as a resource. This takes in a lot of arguments, but not all are required. My suggestion is to start with a simple model, utilizing default values where applicable. Later, we will discuss some specific hyperparameters and their use cases.
#
# #### Instance Types
#
# It is suggested that you use instances that are available in the free tier of usage: `'ml.c4.xlarge'` for training and `'ml.t2.medium'` for deployment.

# %%
output_path=f's3://{bucket}/{prefix}/'

# %%
# import LinearLearner
from sagemaker import LinearLearner



# instantiate LinearLearner
prefix = 'linear-model'


linear_model = LinearLearner(role, 
                             train_instance_count=1, 
                             train_instance_type='ml.c4.xlarge',
                             predictor_type='binary_classifier',
                             output_path=f's3://{bucket}/{prefix}/',
                             sagemaker_session=sagemaker_session)

# %% [markdown]
# ### EXERCISE: Convert data into a RecordSet format
#
# Next, prepare the data for a built-in model by converting the train features and labels into numpy array's of float values. Then you can use the [record_set function](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) to format the data as a RecordSet and prepare it for training!

# %%
# create RecordSet of training data
formatted_train_data = linear_model.record_set(train_features.astype('float32'), train_labels.astype('float32'))

# %% [markdown]
# ### EXERCISE: Train the Estimator
#
# After instantiating your estimator, train it with a call to `.fit()`, passing in the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_model.fit(formatted_train_data)
# Out:
# 2019-12-18 18:14:13 Starting - Starting the training job...
# 2019-12-18 18:14:14 Starting - Launching requested ML instances...
# 2019-12-18 18:15:12 Starting - Preparing the instances for training......
# 2019-12-18 18:15:54 Downloading - Downloading input data...
# 2019-12-18 18:16:35 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [12/18/2019 18:16:51 INFO 140319679149888] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 18:16:51 INFO 140319679149888] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'30', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [12/18/2019 18:16:51 INFO 140319679149888] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 18:16:51 WARNING 140319679149888] Loggers have already been setup.
# Process 1 is a worker.
# [12/18/2019 18:16:51 INFO 140319679149888] Using default worker.
# [2019-12-18 18:16:51.509] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 32, "num_examples": 1, "num_bytes": 168000}
# [12/18/2019 18:16:51 INFO 140319679149888] Create Store: local
# [2019-12-18 18:16:51.555] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 45, "num_examples": 11, "num_bytes": 1848000}
# [12/18/2019 18:16:51 INFO 140319679149888] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f9e5b4c6110>
# [12/18/2019 18:16:51 INFO 140319679149888] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7380754e+04 2.0172710e+00 1.7377546e+00 1.4838167e+00 1.4092460e+00
#  1.3477775e+00 1.3522964e+00 1.1534942e+00 1.2669660e+00 1.0836970e+00
#  1.0095239e+00 1.0078313e+00 9.5693362e-01 9.8929340e-01 9.3015146e-01
#  9.1516358e-01 8.6718285e-01 7.8385258e-01 8.3293241e-01 8.0994713e-01
#  8.2125729e-01 7.8018463e-01 7.2680271e-01 6.2196666e-01 6.1114913e-01
#  5.2118510e-01 4.8469689e-01 3.9093113e-01 3.5660782e-01 2.3808911e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.5053680e+04 -3.4118749e-02 -2.2776984e-02  4.0579541e-03
#   7.8520755e-04  2.2658552e-03  1.6694006e-03 -2.8288031e-03
#  -2.8892295e-03 -7.7784536e-03 -8.9941360e-03 -1.7962107e-02
#   2.3757618e-02  1.0211061e-03  3.8685219e-03  1.3248826e-02
#  -6.7830714e-03  1.0506624e-02  1.1276229e-02 -1.5074703e-02
#  -6.5151202e-03 -2.2918764e-03 -1.1948544e-03  1.2186598e-03
#   4.7219489e-03 -1.0319453e-02 -3.1002718e-03  1.0441339e-03
#   4.7068903e-03  9.0472305e+01]
# <NDArray 30 @cpu(0)>}
# [12/18/2019 18:16:51 INFO 140319679149888] nvidia-smi took: 0.0251758098602 secs to identify 0 gpus
# [12/18/2019 18:16:51 INFO 140319679149888] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1576693011.653197, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576693011.653162}
#
# [2019-12-18 18:16:57.120] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 5466, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12028067847592147, "sum": 0.12028067847592147, "min": 0.12028067847592147}}, "EndTime": 1576693017.120692, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.120583}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11760774234790898, "sum": 0.11760774234790898, "min": 0.11760774234790898}}, "EndTime": 1576693017.120784, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.120769}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12023187668958502, "sum": 0.12023187668958502, "min": 0.12023187668958502}}, "EndTime": 1576693017.120832, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.12082}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11768375611425046, "sum": 0.11768375611425046, "min": 0.11768375611425046}}, "EndTime": 1576693017.120875, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.120864}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012170965972595179, "sum": 0.012170965972595179, "min": 0.012170965972595179}}, "EndTime": 1576693017.120916, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.120905}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012294128593862357, "sum": 0.012294128593862357, "min": 0.012294128593862357}}, "EndTime": 1576693017.120956, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.120945}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012194884098991377, "sum": 0.012194884098991377, "min": 0.012194884098991377}}, "EndTime": 1576693017.120995, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.120985}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01197017336771566, "sum": 0.01197017336771566, "min": 0.01197017336771566}}, "EndTime": 1576693017.121033, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121023}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12017593954076719, "sum": 0.12017593954076719, "min": 0.12017593954076719}}, "EndTime": 1576693017.121074, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121064}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11762624841239584, "sum": 0.11762624841239584, "min": 0.11762624841239584}}, "EndTime": 1576693017.121113, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121103}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12033776705947953, "sum": 0.12033776705947953, "min": 0.12033776705947953}}, "EndTime": 1576693017.121152, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121142}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1176315806403232, "sum": 0.1176315806403232, "min": 0.1176315806403232}}, "EndTime": 1576693017.121191, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121181}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011809654150476408, "sum": 0.011809654150476408, "min": 0.011809654150476408}}, "EndTime": 1576693017.121229, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121219}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0119153048854003, "sum": 0.0119153048854003, "min": 0.0119153048854003}}, "EndTime": 1576693017.121278, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121268}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011837677338221414, "sum": 0.011837677338221414, "min": 0.011837677338221414}}, "EndTime": 1576693017.121315, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121305}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011869691447864974, "sum": 0.011869691447864974, "min": 0.011869691447864974}}, "EndTime": 1576693017.121361, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.12135}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12223889807121238, "sum": 0.12223889807121238, "min": 0.12223889807121238}}, "EndTime": 1576693017.121402, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121392}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11963534603406437, "sum": 0.11963534603406437, "min": 0.11963534603406437}}, "EndTime": 1576693017.121446, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121435}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12235650659685758, "sum": 0.12235650659685758, "min": 0.12235650659685758}}, "EndTime": 1576693017.121485, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121476}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11971866992969608, "sum": 0.11971866992969608, "min": 0.11971866992969608}}, "EndTime": 1576693017.121525, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121515}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018478634733463353, "sum": 0.018478634733463353, "min": 0.018478634733463353}}, "EndTime": 1576693017.121565, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121555}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018477085819608302, "sum": 0.018477085819608302, "min": 0.018477085819608302}}, "EndTime": 1576693017.121608, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121598}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018452576353472083, "sum": 0.018452576353472083, "min": 0.018452576353472083}}, "EndTime": 1576693017.121648, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121638}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018448767811209712, "sum": 0.018448767811209712, "min": 0.018448767811209712}}, "EndTime": 1576693017.121686, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121676}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12293377267655416, "sum": 0.12293377267655416, "min": 0.12293377267655416}}, "EndTime": 1576693017.121724, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121714}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12043833838994779, "sum": 0.12043833838994779, "min": 0.12043833838994779}}, "EndTime": 1576693017.121767, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121756}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12299447806276868, "sum": 0.12299447806276868, "min": 0.12299447806276868}}, "EndTime": 1576693017.121809, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121797}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12035863964521705, "sum": 0.12035863964521705, "min": 0.12035863964521705}}, "EndTime": 1576693017.121866, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121852}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01928780939579759, "sum": 0.01928780939579759, "min": 0.01928780939579759}}, "EndTime": 1576693017.121922, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.121906}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019386083997037243, "sum": 0.019386083997037243, "min": 0.019386083997037243}}, "EndTime": 1576693017.122025, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.122003}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019348949645482116, "sum": 0.019348949645482116, "min": 0.019348949645482116}}, "EndTime": 1576693017.122094, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.122077}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0192602028874072, "sum": 0.0192602028874072, "min": 0.0192602028874072}}, "EndTime": 1576693017.122152, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693017.122141}
#
# [12/18/2019 18:16:57 INFO 140319679149888] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.120280678476
# [12/18/2019 18:16:57 INFO 140319679149888] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.0118096541505
# [12/18/2019 18:16:57 INFO 140319679149888] Epoch 0: Loss improved. Updating best model
# [12/18/2019 18:16:57 INFO 140319679149888] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1576693017.125145, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576693011.653385}
#
# [12/18/2019 18:16:57 INFO 140319679149888] #throughput_metric: host=algo-1, train throughput=36434.2788018 records/second
# 2019-12-18 18:16:48 Training - Training image download completed. Training in progress.[2019-12-18 18:17:03.611] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6484, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.016487704334546573, "sum": 0.016487704334546573, "min": 0.016487704334546573}}, "EndTime": 1576693023.611709, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693023.611623}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0
"Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693023.61315}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019303843162766652, "sum": 0.019303843162766652, "min": 0.019303843162766652}}, "EndTime": 1576693023.613226, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693023.61321}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011535521649835097, "sum": 0.011535521649835097, "min": 0.011535521649835097}}, "EndTime": 1576693023.613287, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693023.61327}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011534554456346598, "sum": 0.011534554456346598, "min": 0.011534554456346598}}, "EndTime": 1576693023.613343, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693023.613328}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011535983309673904, "sum": 0.011535983309673904, "min": 0.011535983309673904}}, "EndTime": 1576693023.6134, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693023.613383}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011534162321282392, "sum": 0.011534162321282392, "min": 0.011534162321282392}}, "EndTime": 1576693023.613451, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693023.613436}
#
# [12/18/2019 18:17:03 INFO 140319679149888] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0164877043345
# [12/18/2019 18:17:03 INFO 140319679149888] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.00481623150221
# [12/18/2019 18:17:03 INFO 140319679149888] Epoch 1: Loss improved. Updating best model
# [12/18/2019 18:17:03 INFO 140319679149888] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1576693023.616337, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576693017.12697}
#
# [12/18/2019 18:17:03 INFO 140319679149888] #throughput_metric: host=algo-1, train throughput=30721.1765614 records/second
# [2019-12-18 18:17:10.028] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6410, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00980349210758305, "sum": 0.00980349210758305, "min": 0.00980349210758305}}, "EndTime": 1576693030.028915, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.028823}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008217066668984878, "sum": 0.008217066668984878, "min": 0.008217066668984878}}, "EndTime": 1576693030.028993, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.028975}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009802218226332161, "sum": 0.009802218226332161, "min": 0.009802218226332161}}, "EndTime": 1576693030.029048, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.029033}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008218379909668736, "sum": 0.008218379909668736, "min": 0.008218379909668736}}, "EndTime": 1576693030.029102, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.029085}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004449325604729317, "sum": 0.004449325604729317, "min": 0.004449325604729317}}, "EndTime": 1576693030.029162, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.029144}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005316323624034623, "sum": 0.005316323624034623, "min": 0.005316323624034623}}, "EndTime": 1576693030.029221, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.029203}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004434381260943772, "sum": 0.004434381260943772, "min": 0.004434381260943772}}, "EndTime": 1576693030.029282, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.029265}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0057307209675785285, "sum": 0.0057307209675785285, "min": 0.0057307209675785285}}, "EndTime": 1576693030.029342, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.029325}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010006475046052406, "sum": 0.010006475046052406, "min": 0.010006475046052406}}, "EndTime": 1576693030.0294, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 
"Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693030.030725}
#
# [12/18/2019 18:17:10 INFO 140319679149888] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.00980349210758
# [12/18/2019 18:17:10 INFO 140319679149888] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00443438126094
# [12/18/2019 18:17:10 INFO 140319679149888] Epoch 2: Loss improved. Updating best model
# [12/18/2019 18:17:10 INFO 140319679149888] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1576693030.033432, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576693023.618463}
#
# [12/18/2019 18:17:10 INFO 140319679149888] #throughput_metric: host=algo-1, train throughput=31077.2968976 records/second
# [2019-12-18 18:17:15.646] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 5610, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007499138185127297, "sum": 0.007499138185127297, "min": 0.007499138185127297}}, "EndTime": 1576693035.646339, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576693035.646255}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006147890221533464, "sum": 0.006147890221533464, "min": 0.006147890221533464}}, "EndTime": 1576693035.646423, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576693035.646405}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00749847056518248, "sum": 0.00749847056518248, "min": 0.00749847056518248}}, "EndTime": 1576693035.64648, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576693035.646464}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006149091643903723, "sum": 0.006149091643903723, "min": 0.006149091643903723}}, "EndTime": 1576693035.646539, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576693035.646522}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00439360372407652, "sum": 0.00439360372407652, "min": 0.00439360372407652}}, "EndTime": 1576693035.646596, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576693035.646579}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005831842964992452, "sum": 0.005831842964992452, "min": 0.005831842964992452}}, "EndTime": 1576693035.646648, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576693035.646637}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004312962155845297, "sum": 0.004312962155845297, "min": 0.004312962155845297}}, "EndTime": 1576693099.513533, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513514}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.003677870414963919, "sum": 0.003677870414963919, "min": 0.003677870414963919}}, "EndTime": 1576693099.5136, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513581}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0036246340427566414, "sum": 0.0036246340427566414, "min": 0.0036246340427566414}}, "EndTime": 1576693099.513675, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513655}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0053706783408944934, "sum": 0.0053706783408944934, "min": 0.0053706783408944934}}, "EndTime": 1576693099.51375, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513731}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.003628212664744363, "sum": 0.003628212664744363, "min": 0.003628212664744363}}, "EndTime": 1576693099.513813, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513795}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005256044153479775, "sum": 0.005256044153479775, "min": 0.005256044153479775}}, "EndTime": 1576693099.513872, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513855}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004909563520445895, "sum": 0.004909563520445895, "min": 0.004909563520445895}}, "EndTime": 1576693099.513925, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513909}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004424344725644768, "sum": 0.004424344725644768, "min": 0.004424344725644768}}, "EndTime": 1576693099.514005, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.513955}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004909822843781668, "sum": 0.004909822843781668, "min": 0.004909822843781668}}, "EndTime": 1576693099.514074, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693099.514055}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004424376103446711, "sum": 0.004424376103446711, "min": 0.004424376103446711}}, "EndTime": 1576693099.514138, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 
% of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1576693099.51805, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576693093.822025}
#
# [12/18/2019 18:18:19 INFO 140319679149888] #throughput_metric: host=algo-1, train throughput=34999.7567182 records/second
# [12/18/2019 18:18:19 WARNING 140319679149888] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/18/2019 18:18:19 WARNING 140319679149888] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-12-18 18:18:19.525] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2019-12-18 18:18:20.175] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 647, "num_examples": 200, "num_bytes": 33493152}
# [2019-12-18 18:18:20.874] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 629, "num_examples": 200, "num_bytes": 33493152}
# [12/18/2019 18:18:20 INFO 140319679149888] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003516721340250867)
# [12/18/2019 18:18:20 INFO 140319679149888] #train_score (algo-1) : ('binary_classification_accuracy', 0.9993730061595875)
# [12/18/2019 18:18:20 INFO 140319679149888] #train_score (algo-1) : ('binary_f_1.000', 0.7980613893376414)
# [12/18/2019 18:18:20 INFO 140319679149888] #train_score (algo-1) : ('precision', 0.7967741935483871)
# [12/18/2019 18:18:20 INFO 140319679149888] #train_score (algo-1) : ('recall', 0.7993527508090615)
# [12/18/2019 18:18:20 INFO 140319679149888] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00351672134025
# [12/18/2019 18:18:20 INFO 140319679149888] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.99937300616
# [12/18/2019 18:18:20 INFO 140319679149888] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.798061389338
# [12/18/2019 18:18:20 INFO 140319679149888] #quality_metric: host=algo-1, train precision <score>=0.796774193548
# [12/18/2019 18:18:20 INFO 140319679149888] #quality_metric: host=algo-1, train recall <score>=0.799352750809
# [12/18/2019 18:18:20 INFO 140319679149888] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [12/18/2019 18:18:20 INFO 140319679149888] Saved checkpoint to "/tmp/tmpPymZrU/mx-mod-0000.params"
# [12/18/2019 18:18:20 INFO 140319679149888] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 89484.39383506775, "sum": 89484.39383506775, "min": 89484.39383506775}, "finalize.time": {"count": 1, "max": 1357.7308654785156, "sum": 1357.7308654785156, "min": 1357.7308654785156}, "initialize.time": {"count": 1, "max": 171.9648838043213, "sum": 171.9648838043213, "min": 171.9648838043213}, "check_early_stopping.time": {"count": 15, "max": 0.9338855743408203, "sum": 11.394977569580078, "min": 0.1850128173828125}, "setuptime": {"count": 1, "max": 24.638891220092773, "sum": 24.638891220092773, "min": 24.638891220092773}, "update.time": {"count": 15, "max": 6489.2120361328125, "sum": 87838.08183670044, "min": 5471.613883972168}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1576693100.884393, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576693011.475749}
# 2019-12-18 18:18:31 Uploading - Uploading generated training model
# 2019-12-18 18:18:31 Completed - Training job completed
# Training seconds: 157
# Billable seconds: 157
# CPU times: user 648 ms, sys: 38.1 ms, total: 686 ms
# Wall time: 4min 42s

# %% [markdown]
# ### EXERCISE: Deploy the trained model
#
# Deploy your model to create a predictor. We'll use this to make predictions on our test data and evaluate the model.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = linear_model.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -------------------------------------------------------------------------------------------------------------!CPU times: user 565 ms, sys: 17.7 ms, total: 583 ms
# Wall time: 9min 9s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to the test data.
#
# According to the deployed [predictor documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor), this predictor expects an `ndarray` of input features and returns a list of Records.
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Let's first test our model on just one test point, to see the resulting list.

# %%
# test one prediction
test_x_np = test_features.astype('float32')
result = linear_predictor.predict(test_x_np[0])

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.00011517386155901477
#     }
#   }
# }
# ]

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 85269   28
# 1                    45  101
#
# Recall:     0.692
# Precision:  0.783
# Accuracy:   0.999

# %% [markdown]
# ## Delete the Endpoint
#
# I've added a convenience function to delete prediction endpoints after we're done with them. And if you're done evaluating the model, you should delete your model endpoint!

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# Deleted linear-learner-2019-12-18-18-14-13-343

# %% [markdown]
# ---
#
# # Model Improvements
#
# The default LinearLearner got a high accuracy, but still classified fraudulent and valid data points incorrectly. Specifically classifying more than 30 points as false negatives (incorrectly labeled, fraudulent transactions), and a little over 30 points as false positives (incorrectly labeled, valid transactions). Let's think about what, during training, could cause this behavior and what we could improve.
#
# **1. Model optimization**
# * If we imagine that we are designing this model for use in a bank application, we know that users do *not* want any valid transactions to be categorized as fraudulent. That is, we want to have as few **false positives** (0s classified as 1s) as possible.
# * On the other hand, if our bank manager asks for an application that will catch almost *all* cases of fraud, even if it means a higher number of false positives, then we'd want as few **false negatives** as possible.
# * To train according to specific product demands and goals, we do not want to optimize for accuracy only. Instead, we want to optimize for a metric that can help us decrease the number of false positives or negatives.
#
# <img src='notebook_ims/precision_recall.png' width=40% />
#
# In this notebook, we'll look at different cases for tuning a model and make an optimization decision, accordingly.
#
# **2. Imbalanced training data**
# * At the start of this notebook, we saw that only about 0.17% of the training data was labeled as fraudulent. So, even if a model labels **all** of our data as valid, it will still have a high accuracy.
# * This may result in some overfitting towards valid data, which accounts for some **false negatives**; cases in which fraudulent data (1) is incorrectly characterized as valid (0).
#
# So, let's address these issues in order; first, tuning our model and optimizing for a specific metric during training, and second, accounting for class imbalance in the training set.

# %% [markdown]
# ## Improvement: Model Tuning
#
# Optimizing according to a specific metric is called **model tuning**, and SageMaker provides a number of ways to automatically tune a model.
#
#
# ### Create a LinearLearner and tune for higher precision
#
# **Scenario:**
# * A bank has asked you to build a model that detects cases of fraud with an accuracy of about 85%.
#
# In this case, we want to build a model that has as many true positives and as few false negatives, as possible. This corresponds to a model with a high **recall**: true positives / (true positives + false negatives).
#
# To aim for a specific metric, LinearLearner offers the hyperparameter `binary_classifier_model_selection_criteria`, which is the model evaluation criteria for the training dataset. A reference to this parameter is in [LinearLearner's documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). We'll also have to further specify the exact value we want to aim for; read more about the details of the parameters, [here](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# I will assume that performance on a training set will be within about 5% of the performance on a test set. So, for a recall of about 85%, I'll aim for a bit higher, 90%.

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall

# %% [markdown]
# ### Train the tuned estimator
#
# Fit the new, tuned estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# 2019-12-18 19:18:20 Starting - Starting the training job...
# 2019-12-18 19:18:22 Starting - Launching requested ML instances...
# 2019-12-18 19:19:17 Starting - Preparing the instances for training......
# 2019-12-18 19:20:12 Downloading - Downloading input data...
# 2019-12-18 19:20:39 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# [12/18/2019 19:20:55 INFO 140209520273216] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 19:20:55 INFO 140209520273216] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'15', u'feature_dim': u'30', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [12/18/2019 19:20:55 INFO 140209520273216] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 19:20:55 WARNING 140209520273216] Loggers have already been setup.
# Process 1 is a worker.
# [12/18/2019 19:20:55 INFO 140209520273216] Using default worker.
# [2019-12-18 19:20:55.713] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 23, "num_examples": 1, "num_bytes": 168000}
# [12/18/2019 19:20:55 INFO 140209520273216] Create Store: local
# [2019-12-18 19:20:55.764] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 50, "num_examples": 11, "num_bytes": 1848000}
# [12/18/2019 19:20:55 INFO 140209520273216] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f84c15125d0>
# [12/18/2019 19:20:55 INFO 140209520273216] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7380754e+04 2.0172710e+00 1.7377546e+00 1.4838167e+00 1.4092460e+00
#  1.3477775e+00 1.3522964e+00 1.1534942e+00 1.2669660e+00 1.0836970e+00
#  1.0095239e+00 1.0078313e+00 9.5693362e-01 9.8929340e-01 9.3015146e-01
#  9.1516358e-01 8.6718285e-01 7.8385258e-01 8.3293241e-01 8.0994713e-01
#  8.2125729e-01 7.8018463e-01 7.2680271e-01 6.2196666e-01 6.1114913e-01
#  5.2118510e-01 4.8469689e-01 3.9093113e-01 3.5660782e-01 2.3808911e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.5053680e+04 -3.4118749e-02 -2.2776984e-02  4.0579541e-03
#   7.8520755e-04  2.2658552e-03  1.6694006e-03 -2.8288031e-03
#  -2.8892295e-03 -7.7784536e-03 -8.9941360e-03 -1.7962107e-02
#   2.3757618e-02  1.0211061e-03  3.8685219e-03  1.3248826e-02
#  -6.7830714e-03  1.0506624e-02  1.1276229e-02 -1.5074703e-02
#  -6.5151202e-03 -2.2918764e-03 -1.1948544e-03  1.2186598e-03
#   4.7219489e-03 -1.0319453e-02 -3.1002718e-03  1.0441339e-03
#   4.7068903e-03  9.0472305e+01]
# <NDArray 30 @cpu(0)>}
# [12/18/2019 19:20:55 INFO 140209520273216] nvidia-smi took: 0.0251839160919 secs to identify 0 gpus
# [12/18/2019 19:20:55 INFO 140209520273216] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1576696855.859149, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576696855.859114}
#
# [2019-12-18 19:21:02.052] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6193, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12028067847592147, "sum": 0.12028067847592147, "min": 0.12028067847592147}}, "EndTime": 1576696862.052794, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.052708}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11760774234790898, "sum": 0.11760774234790898, "min": 0.11760774234790898}}, "EndTime": 1576696862.0529, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.052879}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12023187668958502, "sum": 0.12023187668958502, "min": 0.12023187668958502}}, "EndTime": 1576696862.052958, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.052946}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11768375611425046, "sum": 0.11768375611425046, "min": 0.11768375611425046}}, "EndTime": 1576696862.053016, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.052999}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012170965972595179, "sum": 0.012170965972595179, "min": 0.012170965972595179}}, "EndTime": 1576696862.053074, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053057}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012294128593862357, "sum": 0.012294128593862357, "min": 0.012294128593862357}}, "EndTime": 1576696862.053134, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053117}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.012194884098991377, "sum": 0.012194884098991377, "min": 0.012194884098991377}}, "EndTime": 1576696862.053194, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053178}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01197017336771566, "sum": 0.01197017336771566, "min": 0.01197017336771566}}, "EndTime": 1576696862.053254, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053237}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12017593954076719, "sum": 0.12017593954076719, "min": 0.12017593954076719}}, "EndTime": 1576696862.053314, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053297}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11762624841239584, "sum": 0.11762624841239584, "min": 0.11762624841239584}}, "EndTime": 1576696862.053377, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053359}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12033776705947953, "sum": 0.12033776705947953, "min": 0.12033776705947953}}, "EndTime": 1576696862.053449, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053423}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.1176315806403232, "sum": 0.1176315806403232, "min": 0.1176315806403232}}, "EndTime": 1576696862.053505, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053488}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011809654150476408, "sum": 0.011809654150476408, "min": 0.011809654150476408}}, "EndTime": 1576696862.053562, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053546}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0119153048854003, "sum": 0.0119153048854003, "min": 0.0119153048854003}}, "EndTime": 1576696862.053621, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053603}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011837677338221414, "sum": 0.011837677338221414, "min": 0.011837677338221414}}, "EndTime": 1576696862.05368, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053662}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011869691447864974, "sum": 0.011869691447864974, "min": 0.011869691447864974}}, "EndTime": 1576696862.053739, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053722}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12223889807121238, "sum": 0.12223889807121238, "min": 0.12223889807121238}}, "EndTime": 1576696862.053797, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053781}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11963534603406437, "sum": 0.11963534603406437, "min": 0.11963534603406437}}, "EndTime": 1576696862.053859, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053841}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12235650659685758, "sum": 0.12235650659685758, "min": 0.12235650659685758}}, "EndTime": 1576696862.053912, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053896}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.11971866992969608, "sum": 0.11971866992969608, "min": 0.11971866992969608}}, "EndTime": 1576696862.05397, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.053953}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018478634733463353, "sum": 0.018478634733463353, "min": 0.018478634733463353}}, "EndTime": 1576696862.054028, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054011}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018477085819608302, "sum": 0.018477085819608302, "min": 0.018477085819608302}}, "EndTime": 1576696862.054083, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054066}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018452576353472083, "sum": 0.018452576353472083, "min": 0.018452576353472083}}, "EndTime": 1576696862.054139, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054124}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.018448767811209712, "sum": 0.018448767811209712, "min": 0.018448767811209712}}, "EndTime": 1576696862.054187, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054171}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12293377267655416, "sum": 0.12293377267655416, "min": 0.12293377267655416}}, "EndTime": 1576696862.054239, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054223}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12043833838994779, "sum": 0.12043833838994779, "min": 0.12043833838994779}}, "EndTime": 1576696862.054289, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054276}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12299447806276868, "sum": 0.12299447806276868, "min": 0.12299447806276868}}, "EndTime": 1576696862.054342, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054327}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.12035863964521705, "sum": 0.12035863964521705, "min": 0.12035863964521705}}, "EndTime": 1576696862.054405, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054388}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01928780939579759, "sum": 0.01928780939579759, "min": 0.01928780939579759}}, "EndTime": 1576696862.054472, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054455}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019386083997037243, "sum": 0.019386083997037243, "min": 0.019386083997037243}}, "EndTime": 1576696862.054531, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054514}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019348949645482116, "sum": 0.019348949645482116, "min": 0.019348949645482116}}, "EndTime": 1576696862.054592, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054575}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0192602028874072, "sum": 0.0192602028874072, "min": 0.0192602028874072}}, "EndTime": 1576696862.054657, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576696862.054641}
#
# [12/18/2019 19:21:02 INFO 140209520273216] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.120280678476
# [12/18/2019 19:21:02 INFO 140209520273216] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.0118096541505
# [12/18/2019 19:21:02 INFO 140209520273216] Epoch 0: Loss improved. Updating best model
# [12/18/2019 19:21:02 INFO 140209520273216] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1576696862.05811, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1
"Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299361}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010653095999554774, "sum": 0.010653095999554774, "min": 0.010653095999554774}}, "EndTime": 1576696868.299437, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.29942}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010658007253354519, "sum": 0.010658007253354519, "min": 0.010658007253354519}}, "EndTime": 1576696868.299504, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299487}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.010642193137101791, "sum": 0.010642193137101791, "min": 0.010642193137101791}}, "EndTime": 1576696868.299571, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299554}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021110594529003355, "sum": 0.021110594529003355, "min": 0.021110594529003355}}, "EndTime": 1576696868.299628, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299611}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019307421732188468, "sum": 0.019307421732188468, "min": 0.019307421732188468}}, "EndTime": 1576696868.299683, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299668}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.021116938753942747, "sum": 0.021116938753942747, "min": 0.021116938753942747}}, "EndTime": 1576696868.299741, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299724}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.019303843162766652, "sum": 0.019303843162766652, "min": 0.019303843162766652}}, "EndTime": 1576696868.299802, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299785}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011535521649835097, "sum": 0.011535521649835097, "min": 0.011535521649835097}}, "EndTime": 1576696868.299861, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299844}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011534554456346598, "sum": 0.011534554456346598, "min": 0.011534554456346598}}, "EndTime": 1576696868.299909, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299894}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011535983309673904, "sum": 0.011535983309673904, "min": 0.011535983309673904}}, "EndTime": 1576696868.299962, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299946}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011534162321282392, "sum": 0.011534162321282392, "min": 0.011534162321282392}}, "EndTime": 1576696868.300012, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696868.299997}
#
# [12/18/2019 19:21:08 INFO 140209520273216] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.0164877043345
# [12/18/2019 19:21:08 INFO 140209520273216] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.00481623150221
# [12/18/2019 19:21:08 INFO 140209520273216] Epoch 1: Loss improved. Updating best model
# [12/18/2019 19:21:08 INFO 140209520273216] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1576696868.302582, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576696862.060249}
#
# [12/18/2019 19:21:08 INFO 140209520273216] #throughput_metric: host=algo-1, train throughput=31936.8001678 records/second
# [2019-12-18 19:21:14.220] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 5915, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00980349210758305, "sum": 0.00980349210758305, "min": 0.00980349210758305}}, "EndTime": 1576696874.220269, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.220172}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.008217066668984878, "sum": 0.008217066668984878, "min": 0.008217066668984878}}, "EndTime": 1576696874.220362, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.220342}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.009802218226332161, "sum": 0.009802218226332161, "min": 0.009802218226332161}}, "EndTime": 1576696874.220427, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.220409}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0
"Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.221862}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011531781944198224, "sum": 0.011531781944198224, "min": 0.011531781944198224}}, "EndTime": 1576696874.221902, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.22189}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011537545228723306, "sum": 0.011537545228723306, "min": 0.011537545228723306}}, "EndTime": 1576696874.221957, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.221941}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.01153130613319838, "sum": 0.01153130613319838, "min": 0.01153130613319838}}, "EndTime": 1576696874.222019, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.222002}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011538218728261976, "sum": 0.011538218728261976, "min": 0.011538218728261976}}, "EndTime": 1576696874.222076, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696874.22206}
#
# [12/18/2019 19:21:14 INFO 140209520273216] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.00980349210758
# [12/18/2019 19:21:14 INFO 140209520273216] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.00443438126094
# [12/18/2019 19:21:14 INFO 140209520273216] Epoch 2: Loss improved. Updating best model
# [12/18/2019 19:21:14 INFO 140209520273216] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1576696874.224784, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576696868.304159}
#
# [12/18/2019 19:21:14 INFO 140209520273216] #throughput_metric: host=algo-1, train throughput=33672.2053366 records/second
# [2019-12-18 19:21:20.084] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 5858, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.007499138185127297, "sum": 0.007499138185127297, "min": 0.007499138185127297}}, "EndTime": 1576696880.084741, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576696880.084653}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006147890221533464, "sum": 0.006147890221533464, "min": 0.006147890221533464}}, "EndTime": 1576696880.084842, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576696880.084826}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00749847056518248, "sum": 0.00749847056518248, "min": 0.00749847056518248}}, "EndTime": 1576696880.084913, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576696880.084894}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.006149091643903723, "sum": 0.006149091643903723, "min": 0.006149091643903723}}, "EndTime": 1576696880.084987, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576696880.084966}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.00439360372407652, "sum": 0.00439360372407652, "min": 0.00439360372407652}}, "EndTime": 1576696880.085056, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576696880.085037}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.005831842964992452, "sum": 0.005831842964992452, "min": 0.005831842964992452}}, "EndTime": 1576696880.085118, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576696880.085101}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.004312962155845297, "sum": 0.004312962155845297, "min": 0.004312962155845297}}, "EndTime": 1576696941.925342, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576696941.925328}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.003677870414963919, "sum": 0.003677870414963919, "min": 0.003677870414963919}}, "EndTime": 1576696941.925401, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576696941.925385}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0036246340427566414, "sum": 0.0036246340427566414, "min": 0.0036246340427566414}}, "EndTime": 1576696941.925462, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576696941.925445}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.0053706783408944934, "sum": 0.0053706783408944934, "min": 0.0053706783408944934}}, "EndTime": 1576696941.925523, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576696941.925506}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0
"Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576696941.927069}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.011609716248871693, "sum": 0.011609716248871693, "min": 0.011609716248871693}}, "EndTime": 1576696941.927153, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576696941.927135}
#
# [12/18/2019 19:22:21 INFO 140209520273216] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.00431258915896
# [12/18/2019 19:22:21 INFO 140209520273216] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.00362463404276
# [12/18/2019 19:22:21 INFO 140209520273216] Epoch 14: Loss improved. Updating best model
# [12/18/2019 19:22:21 INFO 140209520273216] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1576696941.929674, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576696936.571398}
#
# [12/18/2019 19:22:21 INFO 140209520273216] #throughput_metric: host=algo-1, train throughput=37206.0421935 records/second
# [12/18/2019 19:22:21 WARNING 140209520273216] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/18/2019 19:22:21 WARNING 140209520273216] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-12-18 19:22:21.936] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2019-12-18 19:22:22.590] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 651, "num_examples": 200, "num_bytes": 33493152}
# [2019-12-18 19:22:23.358] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 695, "num_examples": 200, "num_bytes": 33493152}
# [12/18/2019 19:22:23 INFO 140209520273216] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003516721340250867)
# [12/18/2019 19:22:23 INFO 140209520273216] #train_score (algo-1) : ('binary_classification_accuracy', 0.9810647860195422)
# [12/18/2019 19:22:23 INFO 140209520273216] #train_score (algo-1) : ('binary_f_1.000', 0.12998386725051855)
# [12/18/2019 19:22:23 INFO 140209520273216] #train_score (algo-1) : ('precision', 0.06997518610421836)
# [12/18/2019 19:22:23 INFO 140209520273216] #train_score (algo-1) : ('recall', 0.912621359223301)
# [12/18/2019 19:22:23 INFO 140209520273216] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.00351672134025
# [12/18/2019 19:22:23 INFO 140209520273216] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.98106478602
# [12/18/2019 19:22:23 INFO 140209520273216] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.129983867251
# [12/18/2019 19:22:23 INFO 140209520273216] #quality_metric: host=algo-1, train precision <score>=0.0699751861042
# [12/18/2019 19:22:23 INFO 140209520273216] #quality_metric: host=algo-1, train recall <score>=0.912621359223
# [12/18/2019 19:22:23 INFO 140209520273216] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [12/18/2019 19:22:23 INFO 140209520273216] Saved checkpoint to "/tmp/tmpEYz4K5/mx-mod-0000.params"
# [12/18/2019 19:22:23 INFO 140209520273216] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 87760.901927948, "sum": 87760.901927948, "min": 87760.901927948}, "finalize.time": {"count": 1, "max": 1429.8710823059082, "sum": 1429.8710823059082, "min": 1429.8710823059082}, "initialize.time": {"count": 1, "max": 165.16494750976562, "sum": 165.16494750976562, "min": 165.16494750976562}, "check_early_stopping.time": {"count": 15, "max": 0.8940696716308594, "sum": 10.961771011352539, "min": 0.19502639770507812}, "setuptime": {"count": 1, "max": 24.95098114013672, "sum": 24.95098114013672, "min": 24.95098114013672}, "update.time": {"count": 15, "max": 6242.1839237213135, "sum": 86046.9479560852, "min": 5189.074993133545}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1576696943.371982, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576696855.688481}
# 2019-12-18 19:22:30 Uploading - Uploading generated training model
# 2019-12-18 19:22:30 Completed - Training job completed
# Training seconds: 138
# Billable seconds: 138
# CPU times: user 672 ms, sys: 17 ms, total: 689 ms
# Wall time: 4min 42s

# %% [markdown]
# ### Deploy and evaluate the tuned estimator
#
# Deploy the tuned predictor and evaluate it.
#
# We hypothesized that a tuned model, optimized for a higher recall, would have fewer false negatives (fraudulent transactions incorrectly labeled as valid); did the number of false negatives get reduced after tuning the model?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# --------------------------------------------------------------------------------------------------!CPU times: user 516 ms, sys: 11.8 ms, total: 528 ms
# Wall time: 8min 14s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)    0.0   1.0
# actual (row)
# 0                 83646  1651
# 1                    18   128
#
# Recall:     0.877
# Precision:  0.072
# Accuracy:   0.980

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# Deleted linear-learner-2019-12-18-19-18-20-545

# %% [markdown]
# ---
# ## Improvement: Managing Class Imbalance
#
# We have a model that is tuned to get a higher recall, which aims to reduce the number of false negatives. Earlier, we discussed how class imbalance may actually bias our model towards predicting that all transactions are valid, resulting in higher false negatives and true negatives. It stands to reason that this model could be further improved if we account for this imbalance.
#
# To account for class imbalance during training of a binary classifier, LinearLearner offers the hyperparameter, `positive_example_weight_mult`, which is the weight assigned to positive (1, fraudulent) examples when training a binary classifier. The weight of negative examples (0, valid) is fixed at 1.
#
# ### EXERCISE: Create a LinearLearner with a `positive_example_weight_mult` parameter
#
# In **addition** to tuning a model for higher recall (you may use `linear_recall` as a starting point), you should *add* a parameter that helps account for class imbalance. From the [hyperparameter documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) on `positive_example_weight_mult`, it reads:
# > "If you want the algorithm to choose a weight so that errors in classifying negative vs. positive examples have equal impact on training loss, specify `balanced`."
#
# You could also put in a specific float value, in which case you'd want to weight positive examples more heavily than negative examples, since there are fewer of them.

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role, 
                                train_instance_count=1, 
                                train_instance_type='ml.c4.xlarge', 
                                predictor_type='binary_classifier', 
                                binary_classifier_model_selection_criteria='precision_at_target_recall', 
                                positive_example_weight_mult='balanced', 
                                epochs=25,
                                target_recall=0.9,
                                output_path=output_path,
                                sagemaker_session=sagemaker_session
                               )

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# 2019-12-18 20:02:32 Starting - Starting the training job...
# 2019-12-18 20:02:33 Starting - Launching requested ML instances...
# 2019-12-18 20:03:27 Starting - Preparing the instances for training.........
# 2019-12-18 20:05:01 Downloading - Downloading input data
# 2019-12-18 20:05:01 Training - Downloading the training image...
# 2019-12-18 20:05:16 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [12/18/2019 20:05:19 INFO 139791783171904] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 20:05:19 INFO 139791783171904] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'epochs': u'25', u'positive_example_weight_mult': u'balanced', u'target_recall': u'0.9', u'mini_batch_size': u'1000'}
# [12/18/2019 20:05:19 INFO 139791783171904] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'25', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.9', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'precision_at_target_recall', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 20:05:19 WARNING 139791783171904] Loggers have already been setup.
# Process 1 is a worker.
# [12/18/2019 20:05:19 INFO 139791783171904] Using default worker.
# [2019-12-18 20:05:19.582] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 28, "num_examples": 1, "num_bytes": 168000}
# [12/18/2019 20:05:19 INFO 139791783171904] Create Store: local
# [2019-12-18 20:05:19.667] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 84, "num_examples": 11, "num_bytes": 1848000}
# [12/18/2019 20:05:19 INFO 139791783171904] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f237a6845d0>
# [12/18/2019 20:05:19 INFO 139791783171904] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7380754e+04 2.0172710e+00 1.7377546e+00 1.4838167e+00 1.4092460e+00
#  1.3477775e+00 1.3522964e+00 1.1534942e+00 1.2669660e+00 1.0836970e+00
#  1.0095239e+00 1.0078313e+00 9.5693362e-01 9.8929340e-01 9.3015146e-01
#  9.1516358e-01 8.6718285e-01 7.8385258e-01 8.3293241e-01 8.0994713e-01
#  8.2125729e-01 7.8018463e-01 7.2680271e-01 6.2196666e-01 6.1114913e-01
#  5.2118510e-01 4.8469689e-01 3.9093113e-01 3.5660782e-01 2.3808911e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.5053680e+04 -3.4118749e-02 -2.2776984e-02  4.0579541e-03
#   7.8520755e-04  2.2658552e-03  1.6694006e-03 -2.8288031e-03
#  -2.8892295e-03 -7.7784536e-03 -8.9941360e-03 -1.7962107e-02
#   2.3757618e-02  1.0211061e-03  3.8685219e-03  1.3248826e-02
#  -6.7830714e-03  1.0506624e-02  1.1276229e-02 -1.5074703e-02
#  -6.5151202e-03 -2.2918764e-03 -1.1948544e-03  1.2186598e-03
#   4.7219489e-03 -1.0319453e-02 -3.1002718e-03  1.0441339e-03
#   4.7068903e-03  9.0472305e+01]
# <NDArray 30 @cpu(0)>}
# [12/18/2019 20:05:19 INFO 139791783171904] nvidia-smi took: 0.0251731872559 secs to identify 0 gpus
# [12/18/2019 20:05:19 INFO 139791783171904] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1576699519.860512, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576699519.860475}
#
# [2019-12-18 20:05:26.266] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6405, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7082232412213656, "sum": 0.7082232412213656, "min": 0.7082232412213656}}, "EndTime": 1576699526.266581, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266493}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6032066615885826, "sum": 0.6032066615885826, "min": 0.6032066615885826}}, "EndTime": 1576699526.266676, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.26666}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6402147532707483, "sum": 0.6402147532707483, "min": 0.6402147532707483}}, "EndTime": 1576699526.26673, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266717}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6634917262858482, "sum": 0.6634917262858482, "min": 0.6634917262858482}}, "EndTime": 1576699526.266774, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266763}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7398530055673878, "sum": 0.7398530055673878, "min": 0.7398530055673878}}, "EndTime": 1576699526.266815, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266804}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7115570525547967, "sum": 0.7115570525547967, "min": 0.7115570525547967}}, "EndTime": 1576699526.266855, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266845}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7415007872845061, "sum": 0.7415007872845061, "min": 0.7415007872845061}}, "EndTime": 1576699526.266898, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266887}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7695548713339034, "sum": 0.7695548713339034, "min": 0.7695548713339034}}, "EndTime": 1576699526.266938, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266928}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6221413790448826, "sum": 0.6221413790448826, "min": 0.6221413790448826}}, "EndTime": 1576699526.266979, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.266968}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7004736686974914, "sum": 0.7004736686974914, "min": 0.7004736686974914}}, "EndTime": 1576699526.267027, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.267015}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6789035896799672, "sum": 0.6789035896799672, "min": 0.6789035896799672}}, "EndTime": 1576699526.267076, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.267065}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6853834269154611, "sum": 0.6853834269154611, "min": 0.6853834269154611}}, "EndTime": 1576699526.267119, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.267108}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7147369945660308, "sum": 0.7147369945660308, "min": 0.7147369945660308}}, "EndTime": 1576699526.267166, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576699526.267155}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6907827749204396, "sum": 0.6907827749204396, "min": 0.6907827749204396}}, "EndTime": 1576699526.267246, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1
"Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.366758}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6489381190352703, "sum": 0.6489381190352703, "min": 0.6489381190352703}}, "EndTime": 1576699533.366811, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.366801}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6677852600711075, "sum": 0.6677852600711075, "min": 0.6677852600711075}}, "EndTime": 1576699533.366856, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.366845}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2770549110911, "sum": 1.2770549110911, "min": 1.2770549110911}}, "EndTime": 1576699533.366902, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.366891}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.276157437885227, "sum": 1.276157437885227, "min": 1.276157437885227}}, "EndTime": 1576699533.366949, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.366938}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.276308489775538, "sum": 1.276308489775538, "min": 1.276308489775538}}, "EndTime": 1576699533.366989, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.366979}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2763625534287648, "sum": 1.2763625534287648, "min": 1.2763625534287648}}, "EndTime": 1576699533.367045, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.367029}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3773370293852072, "sum": 1.3773370293852072, "min": 1.3773370293852072}}, "EndTime": 1576699533.367114, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.367096}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4238856302385954, "sum": 1.4238856302385954, "min": 1.4238856302385954}}, "EndTime": 1576699533.367168, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.367154}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3837385049944546, "sum": 1.3837385049944546, "min": 1.3837385049944546}}, "EndTime": 1576699533.367232, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.367202}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4367843123392843, "sum": 1.4367843123392843, "min": 1.4367843123392843}}, "EndTime": 1576699533.367303, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699533.367285}
#
# [12/18/2019 20:05:33 INFO 139791783171904] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.470643175211
# [12/18/2019 20:05:33 INFO 139791783171904] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.440181206401
# [12/18/2019 20:05:33 INFO 139791783171904] Epoch 1: Loss improved. Updating best model
# [12/18/2019 20:05:33 INFO 139791783171904] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1576699533.37132, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576699526.272938}
#
# [12/18/2019 20:05:33 INFO 139791783171904] #throughput_metric: host=algo-1, train throughput=28085.3823588 records/second
# [2019-12-18 20:05:39.485] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6113, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4244570458186931, "sum": 0.4244570458186931, "min": 0.4244570458186931}}, "EndTime": 1576699539.485882, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699539.485792}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4042983170705824, "sum": 0.4042983170705824, "min": 0.4042983170705824}}, "EndTime": 1576699539.485955, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699539.48594}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4170343906268403, "sum": 0.4170343906268403, "min": 0.4170343906268403}}, "EndTime": 1576699539.486025, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699539.486007}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.41189005168358883, "sum": 0.41189005168358883, "min": 0.41189005168358883}}, "EndTime": 1576699539.486094, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 
"Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699539.487731}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4126430021506458, "sum": 1.4126430021506458, "min": 1.4126430021506458}}, "EndTime": 1576699539.487818, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699539.487799}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3802292731970398, "sum": 1.3802292731970398, "min": 1.3802292731970398}}, "EndTime": 1576699539.48788, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699539.487861}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.446908452326329, "sum": 1.446908452326329, "min": 1.446908452326329}}, "EndTime": 1576699539.487948, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699539.487928}
#
# [12/18/2019 20:05:39 INFO 139791783171904] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.424457045819
# [12/18/2019 20:05:39 INFO 139791783171904] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.404298317071
# [12/18/2019 20:05:39 INFO 139791783171904] Epoch 2: Loss improved. Updating best model
# [12/18/2019 20:05:39 INFO 139791783171904] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1576699539.490606, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576699533.371571}
#
# [12/18/2019 20:05:39 INFO 139791783171904] #throughput_metric: host=algo-1, train throughput=32580.2523208 records/second
# [2019-12-18 20:05:45.947] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6455, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4030795570258519, "sum": 0.4030795570258519, "min": 0.4030795570258519}}, "EndTime": 1576699545.947527, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576699545.947431}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3878477777452325, "sum": 0.3878477777452325, "min": 0.3878477777452325}}, "EndTime": 1576699545.94762, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576699545.9476}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39784270335441857, "sum": 0.39784270335441857, "min": 0.39784270335441857}}, "EndTime": 1576699545.947686, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576699545.94767}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39294334668490155, "sum": 0.39294334668490155, "min": 0.39294334668490155}}, "EndTime": 1576699545.947742, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576699545.947726}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.523763106801402, "sum": 0.523763106801402, "min": 0.523763106801402}}, "EndTime": 1576699545.9478, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576699545.947783}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3550703194009599, "sum": 0.3550703194009599, "min": 0.3550703194009599}}, "EndTime": 1576699685.856096, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.856076}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3464747929021941, "sum": 0.3464747929021941, "min": 0.3464747929021941}}, "EndTime": 1576699685.856157, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.856139}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.32975919004660753, "sum": 0.32975919004660753, "min": 0.32975919004660753}}, "EndTime": 1576699685.856225, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.856208}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6101632777458459, "sum": 0.6101632777458459, "min": 0.6101632777458459}}, "EndTime": 1576699685.85629, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.856271}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3294132342697987, "sum": 0.3294132342697987, "min": 0.3294132342697987}}, "EndTime": 1576699685.856356, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.856337}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0

#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2697337256963528, "sum": 1.2697337256963528, "min": 1.2697337256963528}}, "EndTime": 1576699685.857577, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.85756}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3831071285075278, "sum": 1.3831071285075278, "min": 1.3831071285075278}}, "EndTime": 1576699685.857639, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.857622}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2697335070126021, "sum": 1.2697335070126021, "min": 1.2697335070126021}}, "EndTime": 1576699685.857698, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.857681}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.383211315365892, "sum": 1.383211315365892, "min": 1.383211315365892}}, "EndTime": 1576699685.857757, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699685.85774}
#
# [12/18/2019 20:08:05 INFO 139791783171904] #quality_metric: host=algo-1, epoch=24, train binary_classification_weighted_cross_entropy_objective <loss>=0.356358934795
# [12/18/2019 20:08:05 INFO 139791783171904] #early_stopping_criteria_metric: host=algo-1, epoch=24, criteria=binary_classification_weighted_cross_entropy_objective, value=0.32941323427
# [12/18/2019 20:08:05 INFO 139791783171904] Epoch 24: Loss improved. Updating best model
# [12/18/2019 20:08:05 INFO 139791783171904] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 5012, "sum": 5012.0, "min": 5012}, "Total Records Seen": {"count": 1, "max": 4996100, "sum": 4996100.0, "min": 4996100}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 27, "sum": 27.0, "min": 27}}, "EndTime": 1576699685.860489, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 24}, "StartTime": 1576699679.418666}
#
# [12/18/2019 20:08:05 INFO 139791783171904] #throughput_metric: host=algo-1, train throughput=30947.7578832 records/second
# [12/18/2019 20:08:05 WARNING 139791783171904] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/18/2019 20:08:05 WARNING 139791783171904] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-12-18 20:08:05.867] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 53, "duration": 5, "num_examples": 1, "num_bytes": 168000}
# [2019-12-18 20:08:06.532] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 56, "duration": 661, "num_examples": 200, "num_bytes": 33493152}
# [2019-12-18 20:08:07.312] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 58, "duration": 703, "num_examples": 200, "num_bytes": 33493152}
# [12/18/2019 20:08:07 INFO 139791783171904] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.32588931117910525)
# [12/18/2019 20:08:07 INFO 139791783171904] #train_score (algo-1) : ('binary_classification_accuracy', 0.9856894925864248)
# [12/18/2019 20:08:07 INFO 139791783171904] #train_score (algo-1) : ('binary_f_1.000', 0.16358839050131926)
# [12/18/2019 20:08:07 INFO 139791783171904] #train_score (algo-1) : ('precision', 0.08994197292069632)
# [12/18/2019 20:08:07 INFO 139791783171904] #train_score (algo-1) : ('recall', 0.9029126213592233)
# [12/18/2019 20:08:07 INFO 139791783171904] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.325889311179
# [12/18/2019 20:08:07 INFO 139791783171904] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.985689492586
# [12/18/2019 20:08:07 INFO 139791783171904] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.163588390501
# [12/18/2019 20:08:07 INFO 139791783171904] #quality_metric: host=algo-1, train precision <score>=0.0899419729207
# [12/18/2019 20:08:07 INFO 139791783171904] #quality_metric: host=algo-1, train recall <score>=0.902912621359
# [12/18/2019 20:08:07 INFO 139791783171904] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [12/18/2019 20:08:07 INFO 139791783171904] Saved checkpoint to "/tmp/tmp7BztfE/mx-mod-0000.params"
# [12/18/2019 20:08:07 INFO 139791783171904] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 167854.3131351471, "sum": 167854.3131351471, "min": 167854.3131351471}, "finalize.time": {"count": 1, "max": 1453.465223312378, "sum": 1453.465223312378, "min": 1453.465223312378}, "initialize.time": {"count": 1, "max": 303.15709114074707, "sum": 303.15709114074707, "min": 303.15709114074707}, "check_early_stopping.time": {"count": 25, "max": 0.9810924530029297, "sum": 22.062301635742188, "min": 0.762939453125}, "setuptime": {"count": 1, "max": 26.196956634521484, "sum": 26.196956634521484, "min": 26.196956634521484}, "update.time": {"count": 25, "max": 7260.890007019043, "sum": 165957.50832557678, "min": 6091.165781021118}, "epochs": {"count": 1, "max": 25, "sum": 25.0, "min": 25}}, "EndTime": 1576699687.32769, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576699519.553507}
# 2019-12-18 20:08:10 Uploading - Uploading generated training model
# 2019-12-18 20:08:10 Completed - Training job completed
# Training seconds: 215
# Billable seconds: 215
# CPU times: user 883 ms, sys: 65.6 ms, total: 949 ms
# Wall time: 6min 13s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -------------------------------------------------------------------------------------------------------------!CPU times: user 553 ms, sys: 27.1 ms, total: 580 ms
# Wall time: 9min 10s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 85268   29
# 1                    32  114
#
# Recall:     0.781
# Precision:  0.797
# Accuracy:   0.999

# %%
print('Metrics for balanced, LinearLearner.\n Fixed recall, balanced set, optimize precision')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#  Fixed recall, balanced set, optimize precision
# prediction (col)    0.0   1.0
# actual (row)
# 0                 84054  1243
# 1                    14   132
#
# Recall:     0.904
# Precision:  0.096
# Accuracy:   0.985

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# Deleted linear-learner-2019-12-18-20-02-32-601

# %% [markdown]
# A note on metric variability:
#
# The above model is tuned for the best possible precision with recall fixed at about 90%. The recall is fixed at 90% during training, but may vary when we apply our trained model to a test set of data.

# %% [markdown]
# ---
# ## Model Design
#
# Now that you've seen how to tune and balance a LinearLearner. Create, train and deploy your own model. This exercise is meant to be more open-ended, so that you get practice with the steps involved in designing a model and deploying it.
#
# ### EXERCISE: Train and deploy a LinearLearner with appropriate hyperparameters, according to the given scenario
#
# **Scenario:**
# * A bank has asked you to build a model that optimizes for a good user experience; users should only ever have up to about 15% of their valid transactions flagged as fraudulent.
#
# This requires that you make a design decision: Given the above scenario, what metric (and value) should you aim for during training?
#
# You may assume that performance on a training set will be within about 5-10% of the performance on a test set. For example, if you get 80% on a training set, you can assume that you'll get between about 70-90% accuracy on a test set.
#
# Your final model should account for class imbalance and be appropriately tuned.

# %%
# %%time
# instantiate and train a LinearLearner

# include params for tuning for higher precision
# *and* account for class imbalance in training data

linear_fps = LinearLearner(role, 
                           train_instance_count=1, 
                           train_instance_type='ml.c4.xlarge',
                           predictor_type='binary_classifier',
                           binary_classifier_model_selection_criteria='recall_at_target_precision',
                           target_precision=0.85,
                           positive_example_weight_mult='balanced',
                           output_path=output_path,
                           sagemaker_session=sagemaker_session
                          )
# Out:
# CPU times: user 2.02 ms, sys: 65 µs, total: 2.09 ms
# Wall time: 2.1 ms

# %%
# %%time 
# deploy and evaluate a predictor
linear_fps.fit(formatted_train_data)
# Out:
# 2019-12-18 20:36:05 Starting - Starting the training job...
# 2019-12-18 20:36:07 Starting - Launching requested ML instances...
# 2019-12-18 20:37:03 Starting - Preparing the instances for training.........
# 2019-12-18 20:38:33 Downloading - Downloading input data
# 2019-12-18 20:38:33 Training - Downloading the training image...
# 2019-12-18 20:38:52 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [12/18/2019 20:38:55 INFO 139727624554304] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 20:38:55 INFO 139727624554304] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'positive_example_weight_mult': u'balanced', u'predictor_type': u'binary_classifier', u'feature_dim': u'30', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'target_precision': u'0.85', u'mini_batch_size': u'1000'}
# [12/18/2019 20:38:55 INFO 139727624554304] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'30', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'recall_at_target_precision', u'use_lr_scheduler': u'true', u'target_precision': u'0.85', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'balanced', u'l1': u'auto', u'margin': u'1.0'}
# [12/18/2019 20:38:55 WARNING 139727624554304] Loggers have already been setup.
# Process 1 is a worker.
# [12/18/2019 20:38:55 INFO 139727624554304] Using default worker.
# [2019-12-18 20:38:55.536] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 23, "num_examples": 1, "num_bytes": 168000}
# [12/18/2019 20:38:55 INFO 139727624554304] Create Store: local
# [2019-12-18 20:38:55.596] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 58, "num_examples": 11, "num_bytes": 1848000}
# [12/18/2019 20:38:55 INFO 139727624554304] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f148a17c5d0>
# [12/18/2019 20:38:55 INFO 139727624554304] Scaling model computed with parameters:
#  {'stdev_weight':
# [4.7380754e+04 2.0172710e+00 1.7377546e+00 1.4838167e+00 1.4092460e+00
#  1.3477775e+00 1.3522964e+00 1.1534942e+00 1.2669660e+00 1.0836970e+00
#  1.0095239e+00 1.0078313e+00 9.5693362e-01 9.8929340e-01 9.3015146e-01
#  9.1516358e-01 8.6718285e-01 7.8385258e-01 8.3293241e-01 8.0994713e-01
#  8.2125729e-01 7.8018463e-01 7.2680271e-01 6.2196666e-01 6.1114913e-01
#  5.2118510e-01 4.8469689e-01 3.9093113e-01 3.5660782e-01 2.3808911e+02]
# <NDArray 30 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 9.5053680e+04 -3.4118749e-02 -2.2776984e-02  4.0579541e-03
#   7.8520755e-04  2.2658552e-03  1.6694006e-03 -2.8288031e-03
#  -2.8892295e-03 -7.7784536e-03 -8.9941360e-03 -1.7962107e-02
#   2.3757618e-02  1.0211061e-03  3.8685219e-03  1.3248826e-02
#  -6.7830714e-03  1.0506624e-02  1.1276229e-02 -1.5074703e-02
#  -6.5151202e-03 -2.2918764e-03 -1.1948544e-03  1.2186598e-03
#   4.7219489e-03 -1.0319453e-02 -3.1002718e-03  1.0441339e-03
#   4.7068903e-03  9.0472305e+01]
# <NDArray 30 @cpu(0)>}
# [12/18/2019 20:38:55 INFO 139727624554304] nvidia-smi took: 0.0252130031586 secs to identify 0 gpus
# [12/18/2019 20:38:55 INFO 139727624554304] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1576701535.757742, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576701535.757702}
#
# [2019-12-18 20:39:01.957] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6199, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7082232412213656, "sum": 0.7082232412213656, "min": 0.7082232412213656}}, "EndTime": 1576701541.957588, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.957498}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6032066615885826, "sum": 0.6032066615885826, "min": 0.6032066615885826}}, "EndTime": 1576701541.957659, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.957643}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6402147532707483, "sum": 0.6402147532707483, "min": 0.6402147532707483}}, "EndTime": 1576701541.957717, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.9577}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6634917262858482, "sum": 0.6634917262858482, "min": 0.6634917262858482}}, "EndTime": 1576701541.95778, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.957763}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7398530055673878, "sum": 0.7398530055673878, "min": 0.7398530055673878}}, "EndTime": 1576701541.957839, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.957822}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7115570525547967, "sum": 0.7115570525547967, "min": 0.7115570525547967}}, "EndTime": 1576701541.957897, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.957879}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7415007872845061, "sum": 0.7415007872845061, "min": 0.7415007872845061}}, "EndTime": 1576701541.957955, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.957938}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7695548713339034, "sum": 0.7695548713339034, "min": 0.7695548713339034}}, "EndTime": 1576701541.958014, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.957997}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6221413790448826, "sum": 0.6221413790448826, "min": 0.6221413790448826}}, "EndTime": 1576701541.958074, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958058}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7004736686974914, "sum": 0.7004736686974914, "min": 0.7004736686974914}}, "EndTime": 1576701541.958139, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958121}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6789035896799672, "sum": 0.6789035896799672, "min": 0.6789035896799672}}, "EndTime": 1576701541.958198, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.95818}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6853834269154611, "sum": 0.6853834269154611, "min": 0.6853834269154611}}, "EndTime": 1576701541.958258, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958242}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7147369945660308, "sum": 0.7147369945660308, "min": 0.7147369945660308}}, "EndTime": 1576701541.958318, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.9583}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6907827749204396, "sum": 0.6907827749204396, "min": 0.6907827749204396}}, "EndTime": 1576701541.958386, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.95836}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7092328661818001, "sum": 0.7092328661818001, "min": 0.7092328661818001}}, "EndTime": 1576701541.958442, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958427}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6841663624749111, "sum": 0.6841663624749111, "min": 0.6841663624749111}}, "EndTime": 1576701541.958496, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958483}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7411663159701093, "sum": 0.7411663159701093, "min": 0.7411663159701093}}, "EndTime": 1576701541.95855, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958534}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6392192561470683, "sum": 0.6392192561470683, "min": 0.6392192561470683}}, "EndTime": 1576701541.958607, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.95859}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6692582819186264, "sum": 0.6692582819186264, "min": 0.6692582819186264}}, "EndTime": 1576701541.958666, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958649}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6985902914689414, "sum": 0.6985902914689414, "min": 0.6985902914689414}}, "EndTime": 1576701541.958721, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958705}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7359315735131652, "sum": 0.7359315735131652, "min": 0.7359315735131652}}, "EndTime": 1576701541.958777, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958761}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7003867652452171, "sum": 0.7003867652452171, "min": 0.7003867652452171}}, "EndTime": 1576701541.958834, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958817}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6932431457366176, "sum": 0.6932431457366176, "min": 0.6932431457366176}}, "EndTime": 1576701541.958901, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958884}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7642358573932744, "sum": 0.7642358573932744, "min": 0.7642358573932744}}, "EndTime": 1576701541.958962, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.958945}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.27542950040731, "sum": 1.27542950040731, "min": 1.27542950040731}}, "EndTime": 1576701541.959027, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959011}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2767916137081894, "sum": 1.2767916137081894, "min": 1.2767916137081894}}, "EndTime": 1576701541.959084, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959069}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3089519306738773, "sum": 1.3089519306738773, "min": 1.3089519306738773}}, "EndTime": 1576701541.95915, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959132}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2847145827403619, "sum": 1.2847145827403619, "min": 1.2847145827403619}}, "EndTime": 1576701541.959236, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959217}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4499572094481195, "sum": 1.4499572094481195, "min": 1.4499572094481195}}, "EndTime": 1576701541.959301, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959285}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.5189320660308379, "sum": 1.5189320660308379, "min": 1.5189320660308379}}, "EndTime": 1576701541.95936, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959345}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4365772028017283, "sum": 1.4365772028017283, "min": 1.4365772028017283}}, "EndTime": 1576701541.959411, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959397}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.493558899309168, "sum": 1.493558899309168, "min": 1.493558899309168}}, "EndTime": 1576701541.95946, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701541.959447}
#
# [12/18/2019 20:39:01 INFO 139727624554304] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.708223241221
# [12/18/2019 20:39:01 INFO 139727624554304] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.603206661589
# [12/18/2019 20:39:01 INFO 139727624554304] Epoch 0: Loss improved. Updating best model
# [12/18/2019 20:39:01 INFO 139727624554304] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 212, "sum": 212.0, "min": 212}, "Total Records Seen": {"count": 1, "max": 211364, "sum": 211364.0, "min": 211364}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1576701541.962829, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1576701535.757929}
#
# [12/18/2019 20:39:01 INFO 139727624554304] #throughput_metric: host=algo-1, train throughput=32129.5264079 records/second
# [2019-12-18 20:39:08.829] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6865, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.47064317521138405, "sum": 0.47064317521138405, "min": 0.47064317521138405}}, "EndTime": 1576701548.829446, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829253}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.44018120640126907, "sum": 0.44018120640126907, "min": 0.44018120640126907}}, "EndTime": 1576701548.829539, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829522}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.45840211755187066, "sum": 0.45840211755187066, "min": 0.45840211755187066}}, "EndTime": 1576701548.829587, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829575}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4534219639457051, "sum": 0.4534219639457051, "min": 0.4534219639457051}}, "EndTime": 1576701548.829629, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829618}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6887826287351062, "sum": 0.6887826287351062, "min": 0.6887826287351062}}, "EndTime": 1576701548.829669, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829658}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.9465577787082998, "sum": 0.9465577787082998, "min": 0.9465577787082998}}, "EndTime": 1576701548.829708, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829697}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6770931944343912, "sum": 0.6770931944343912, "min": 0.6770931944343912}}, "EndTime": 1576701548.829763, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829741}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.796883041381836, "sum": 0.796883041381836, "min": 0.796883041381836}}, "EndTime": 1576701548.829802, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829792}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4551329885511542, "sum": 0.4551329885511542, "min": 0.4551329885511542}}, "EndTime": 1576701548.82984, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.82983}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4641964686408115, "sum": 0.4641964686408115, "min": 0.4641964686408115}}, "EndTime": 1576701548.829877, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829867}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4607569058672268, "sum": 0.4607569058672268, "min": 0.4607569058672268}}, "EndTime": 1576701548.829914, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829905}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.459056244969967, "sum": 0.459056244969967, "min": 0.459056244969967}}, "EndTime": 1576701548.829952, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829942}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7051470545859793, "sum": 0.7051470545859793, "min": 0.7051470545859793}}, "EndTime": 1576701548.829988, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.829979}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8716587857385376, "sum": 0.8716587857385376, "min": 0.8716587857385376}}, "EndTime": 1576701548.830029, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830019}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.7251775813462147, "sum": 0.7251775813462147, "min": 0.7251775813462147}}, "EndTime": 1576701548.830067, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830057}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.8800240972509337, "sum": 0.8800240972509337, "min": 0.8800240972509337}}, "EndTime": 1576701548.830106, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830096}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5618657581578547, "sum": 0.5618657581578547, "min": 0.5618657581578547}}, "EndTime": 1576701548.830144, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830134}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.551992152611814, "sum": 0.551992152611814, "min": 0.551992152611814}}, "EndTime": 1576701548.830186, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830175}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.5537763308424446, "sum": 0.5537763308424446, "min": 0.5537763308424446}}, "EndTime": 1576701548.830225, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830215}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.557069258800104, "sum": 0.557069258800104, "min": 0.557069258800104}}, "EndTime": 1576701548.830264, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830254}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6380437680536778, "sum": 0.6380437680536778, "min": 0.6380437680536778}}, "EndTime": 1576701548.830303, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830292}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6862882548480777, "sum": 0.6862882548480777, "min": 0.6862882548480777}}, "EndTime": 1576701548.830341, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830332}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6489381190352703, "sum": 0.6489381190352703, "min": 0.6489381190352703}}, "EndTime": 1576701548.830383, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830368}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.6677852600711075, "sum": 0.6677852600711075, "min": 0.6677852600711075}}, "EndTime": 1576701548.830442, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830426}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2770549110911, "sum": 1.2770549110911, "min": 1.2770549110911}}, "EndTime": 1576701548.830494, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830479}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.276157437885227, "sum": 1.276157437885227, "min": 1.276157437885227}}, "EndTime": 1576701548.830552, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830535}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.276308489775538, "sum": 1.276308489775538, "min": 1.276308489775538}}, "EndTime": 1576701548.830612, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830594}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2763625534287648, "sum": 1.2763625534287648, "min": 1.2763625534287648}}, "EndTime": 1576701548.83067, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830654}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3773370293852072, "sum": 1.3773370293852072, "min": 1.3773370293852072}}, "EndTime": 1576701548.830735, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830718}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4238856302385954, "sum": 1.4238856302385954, "min": 1.4238856302385954}}, "EndTime": 1576701548.830803, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830784}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3837385049944546, "sum": 1.3837385049944546, "min": 1.3837385049944546}}, "EndTime": 1576701548.830862, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830845}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4367843123392843, "sum": 1.4367843123392843, "min": 1.4367843123392843}}, "EndTime": 1576701548.830921, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701548.830904}
#
# [12/18/2019 20:39:08 INFO 139727624554304] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.470643175211
# [12/18/2019 20:39:08 INFO 139727624554304] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.440181206401
# [12/18/2019 20:39:08 INFO 139727624554304] Epoch 1: Loss improved. Updating best model
# [12/18/2019 20:39:08 INFO 139727624554304] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 412, "sum": 412.0, "min": 412}, "Total Records Seen": {"count": 1, "max": 410728, "sum": 410728.0, "min": 410728}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1576701548.83355, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1576701541.963091}
#
# [12/18/2019 20:39:08 INFO 139727624554304] #throughput_metric: host=algo-1, train throughput=29016.9830073 records/second
# [2019-12-18 20:39:15.038] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch":

#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2753779732402246, "sum": 1.2753779732402246, "min": 1.2753779732402246}}, "EndTime": 1576701555.039831, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.039816}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2761590189718122, "sum": 1.2761590189718122, "min": 1.2761590189718122}}, "EndTime": 1576701555.039899, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.039882}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.275081174304138, "sum": 1.275081174304138, "min": 1.275081174304138}}, "EndTime": 1576701555.039968, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.03995}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2762164570410648, "sum": 1.2762164570410648, "min": 1.2762164570410648}}, "EndTime": 1576701555.040034, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.040017}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3792651845654051, "sum": 1.3792651845654051, "min": 1.3792651845654051}}, "EndTime": 1576701555.040093, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.040078}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.4126430021506458, "sum": 1.4126430021506458, "min": 1.4126430021506458}}, "EndTime": 1576701555.04015, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.040134}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3802292731970398, "sum": 1.3802292731970398, "min": 1.3802292731970398}}, "EndTime": 1576701555.040211, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.040195}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.446908452326329, "sum": 1.446908452326329, "min": 1.446908452326329}}, "EndTime": 1576701555.040273, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701555.040258}
#
# [12/18/2019 20:39:15 INFO 139727624554304] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.424457045819
# [12/18/2019 20:39:15 INFO 139727624554304] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.404298317071
# [12/18/2019 20:39:15 INFO 139727624554304] Epoch 2: Loss improved. Updating best model
# [12/18/2019 20:39:15 INFO 139727624554304] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 612, "sum": 612.0, "min": 612}, "Total Records Seen": {"count": 1, "max": 610092, "sum": 610092.0, "min": 610092}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1576701555.042908, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1576701548.834944}
#
# [12/18/2019 20:39:15 INFO 139727624554304] #throughput_metric: host=algo-1, train throughput=32113.6125475 records/second
# [2019-12-18 20:39:21.623] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6579, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.4030795570258519, "sum": 0.4030795570258519, "min": 0.4030795570258519}}, "EndTime": 1576701561.624078, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576701561.623972}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3878477777452325, "sum": 0.3878477777452325, "min": 0.3878477777452325}}, "EndTime": 1576701561.624178, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576701561.624156}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39784270335441857, "sum": 0.39784270335441857, "min": 0.39784270335441857}}, "EndTime": 1576701561.624246, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576701561.624227}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.39294334668490155, "sum": 0.39294334668490155, "min": 0.39294334668490155}}, "EndTime": 1576701561.624311, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576701561.624293}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.523763106801402, "sum": 0.523763106801402, "min": 0.523763106801402}}, "EndTime": 1576701561.624375, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1576701561.624356}
#
# ...
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0.3580070311579872, "sum": 0.3580070311579872, "min": 0.3580070311579872}}, "EndTime": 1576701631.018451, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576701631.018433}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 0

#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2770905997884932, "sum": 1.2770905997884932, "min": 1.2770905997884932}}, "EndTime": 1576701631.019759, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576701631.019743}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.392919357376482, "sum": 1.392919357376482, "min": 1.392919357376482}}, "EndTime": 1576701631.019806, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576701631.019795}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.2771074240219653, "sum": 1.2771074240219653, "min": 1.2771074240219653}}, "EndTime": 1576701631.019859, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576701631.019843}
#
# #metrics {"Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"count": 1, "max": 1.3930636981599893, "sum": 1.3930636981599893, "min": 1.3930636981599893}}, "EndTime": 1576701631.019918, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576701631.019902}
#
# [12/18/2019 20:40:31 INFO 139727624554304] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.359584578854
# [12/18/2019 20:40:31 INFO 139727624554304] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.348544497198
# [12/18/2019 20:40:31 INFO 139727624554304] Epoch 14: Loss improved. Updating best model
# [12/18/2019 20:40:31 INFO 139727624554304] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Batches Since Last Reset": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "Number of Records Since Last Reset": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Total Batches Seen": {"count": 1, "max": 3012, "sum": 3012.0, "min": 3012}, "Total Records Seen": {"count": 1, "max": 3002460, "sum": 3002460.0, "min": 3002460}, "Max Records Seen Between Resets": {"count": 1, "max": 199364, "sum": 199364.0, "min": 199364}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1576701631.022669, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1576701624.649565}
#
# [12/18/2019 20:40:31 INFO 139727624554304] #throughput_metric: host=algo-1, train throughput=31281.6264279 records/second
# [12/18/2019 20:40:31 WARNING 139727624554304] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/18/2019 20:40:31 WARNING 139727624554304] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-12-18 20:40:31.031] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 6, "num_examples": 1, "num_bytes": 168000}
# [2019-12-18 20:40:31.706] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 671, "num_examples": 200, "num_bytes": 33493152}
# [2019-12-18 20:40:32.459] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 683, "num_examples": 200, "num_bytes": 33493152}
# [12/18/2019 20:40:32 INFO 139727624554304] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.3285627291062434)
# [12/18/2019 20:40:32 INFO 139727624554304] #train_score (algo-1) : ('binary_classification_accuracy', 0.011526654762143616)
# [12/18/2019 20:40:32 INFO 139727624554304] #train_score (algo-1) : ('binary_f_1.000', 0.003126201412355072)
# [12/18/2019 20:40:32 INFO 139727624554304] #train_score (algo-1) : ('precision', 0.0015655478150728309)
# [12/18/2019 20:40:32 INFO 139727624554304] #train_score (algo-1) : ('recall', 1.0)
# [12/18/2019 20:40:32 INFO 139727624554304] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.328562729106
# [12/18/2019 20:40:32 INFO 139727624554304] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.0115266547621
# [12/18/2019 20:40:32 INFO 139727624554304] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.00312620141236
# [12/18/2019 20:40:32 INFO 139727624554304] #quality_metric: host=algo-1, train precision <score>=0.00156554781507
# [12/18/2019 20:40:32 INFO 139727624554304] #quality_metric: host=algo-1, train recall <score>=1.0
# [12/18/2019 20:40:32 INFO 139727624554304] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [12/18/2019 20:40:32 INFO 139727624554304] Saved checkpoint to "/tmp/tmpyMTVvU/mx-mod-0000.params"
# [12/18/2019 20:40:32 INFO 139727624554304] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 97038.45715522766, "sum": 97038.45715522766, "min": 97038.45715522766}, "finalize.time": {"count": 1, "max": 1437.7679824829102, "sum": 1437.7679824829102, "min": 1437.7679824829102}, "initialize.time": {"count": 1, "max": 239.50815200805664, "sum": 239.50815200805664, "min": 239.50815200805664}, "check_early_stopping.time": {"count": 15, "max": 1.0640621185302734, "sum": 12.559652328491211, "min": 0.7488727569580078}, "setuptime": {"count": 1, "max": 24.049043655395508, "sum": 24.049043655395508, "min": 24.049043655395508}, "update.time": {"count": 15, "max": 6999.719858169556, "sum": 95244.10343170166, "min": 5792.805910110474}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1576701632.47339, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1576701535.51291}
# 2019-12-18 20:40:41 Completed - Training job completed
# Training seconds: 139
# Billable seconds: 139
# CPU times: user 711 ms, sys: 34.5 ms, total: 745 ms
# Wall time: 5min 13s

# %%
balanced_high_precision = linear_fps.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# -------------------------------------------------------------------------------------------------------------!

# %%
print('Metrics for optimized user experience, LinearLearner.\n Fixed precision, balanced set, optimize recall \n')

metrics_high_precision = evaluate(balanced_high_precision, 
                                  test_features.astype('float32'), 
                                  test_labels, 
                                  verbose=True)
# Out:
# Metrics for optimized user experience, LinearLearner.
#  Fixed precision, balanced set, optimize recall
#
# prediction (col)  0.0    1.0
# actual (row)
# 0                 818  84479
# 1                   0    146
#
# Recall:     1.000
# Precision:  0.002
# Accuracy:   0.011

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation 
delete_endpoint(balanced_high_precision)
# Out:
# Deleted linear-learner-2019-12-18-20-36-05-183

# %% [markdown]
# ## Final Cleanup!
#
# * Double check that you have deleted all your endpoints.
# * I'd also suggest manually deleting your S3 bucket, models, and endpoint configurations directly from your AWS console.
#
# You can find thorough cleanup instructions, [in the documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html).

# %% [markdown]
# ---
# # Conclusion
#
# In this notebook, you saw how to train and deploy a LinearLearner in SageMaker. This model is well-suited for a binary classification task that involves specific design decisions and managing class imbalance in the training set.
#
# Following the steps of a machine learning workflow, you loaded in some credit card transaction data, explored that data and prepared it for model training. Then trained, deployed, and evaluated several models, according to different design considerations!
